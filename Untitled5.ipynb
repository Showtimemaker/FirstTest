# %%
import pandas as pd
data1 =pd.read_excel("C:\\Users\\周恒\\Desktop\\编号1修改1.xlsx")
data2 =pd.read_excel("C:\\Users\\周恒\\Desktop\\编号2修改1.xlsx")
data1.head()
# Out:
#    编号     厚度    孔隙率  压缩回弹性率   过滤阻力    过滤效率     透气性
# 0   1  1.715  93.52   77.84   8.13   4.967  777.10
# 1   2  1.830  93.93   86.23  10.47   1.933  795.57
# 2   3  1.890  94.12   82.12  11.87   4.300  564.93
# 3   4  2.095  94.70   83.01  13.90  11.767  474.50
# 4   5  2.235  95.03   86.04  19.23  20.767  347.23

# %%
data2.head()
# Out:
#    编号     厚度    孔隙率  压缩回弹性率    过滤阻力    过滤效率      透气性
# 0   1  2.810  96.28   83.20   7.533  19.967  1019.67
# 1   1  2.910  96.41   86.65   7.200  24.967   968.63
# 2   1  3.425  96.95   94.33  10.133  34.600   643.40
# 3   1  3.400  96.93   82.88  10.600  33.900   603.17
# 4   1  3.845  97.30   75.97  15.700  54.500   405.83

# %%
res=pd.DataFrame(data2.values-data1.values,
                  columns=["厚度","孔隙率","压缩回弹性率","过滤阻力","过滤效率","透气性"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19020/1611526407.py in <module>
# ----> 1 res=pd.DataFrame(data2.values-data1.values,
#       2                   columns=["厚度","孔隙率","压缩回弹性率","过滤阻力","过滤效率","透气性"])
#
# D:\Anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     670                 )
#     671             else:
# --> 672                 mgr = ndarray_to_mgr(
#     673                     data,
#     674                     index,
#
# D:\Anaconda3\lib\site-packages\pandas\core\internals\construction.py in ndarray_to_mgr(values, index, columns, dtype, copy, typ)
#     322     )
#     323
# --> 324     _check_values_indices_shape_match(values, index, columns)
#     325
#     326     if typ == "array":
#
# D:\Anaconda3\lib\site-packages\pandas\core\internals\construction.py in _check_values_indices_shape_match(values, index, columns)
#     391         passed = values.shape
#     392         implied = (len(index), len(columns))
# --> 393         raise ValueError(f"Shape of passed values is {passed}, indices imply {implied}")
#     394
#     395
#
# ValueError: Shape of passed values is (25, 7), indices imply (25, 6)
